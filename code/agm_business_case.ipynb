# %% [markdown]
# # Create the stations, lines, and travel times table for BART system

# %%
import csv

import math
import numpy as np
import pandas as pd

import psycopg2

import json

import neo4j

# %%
def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)
cursor = connection.cursor()

# %%
def my_read_csv_file(file_name, limit):
    "read the csv file and print only the first limit rows"
    
    csv_file = open(file_name, "r")
    
    csv_data = csv.reader(csv_file)
    
    i = 0
    
    for row in csv_data:
        i += 1
        if i <= limit:
            print(row)
            
    print("\nPrinted ", min(limit, i), "lines of ", i, "total lines.")

# %%
# create the stations table and load data

connection.rollback()

query = """

drop table if exists stations; 
create table stations (
  station varchar(32),
  latitude numeric(9,6),
  longitude numeric(9,6),
  transfer_time numeric(3),
  primary key (station)
);


copy stations
from '/user/projects/project-3-peeti-ucberkeley/code/data/stations.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

my_read_csv_file("data/stations.csv", limit=10)
# Out:
# ['station', 'latitude', 'longitude', 'transfer_time']
# ['12th Street', '37.803608', '-122.272006', '282']
# ['16th Street Mission', '37.764847', '-122.420042', '287']
# ['19th Street', '37.807869', '-122.26898', '67']
# ['24th Street Mission', '37.752', '-122.4187', '277']
# ['Antioch', '37.996281', '-121.783404', '0']
# ['Ashby', '37.853068', '-122.269957', '299']
# ['Balboa Park', '37.721667', '-122.4475', '48']
# ['Bay Fair', '37.697', '-122.1265', '63']
# ['Berryessa', '37.368361', '-121.874655', '288']
#
# Printed  10 lines of  51 total lines.

# %%
#create lines table and load data

connection.rollback()

query = """

drop table if exists lines;

create table lines (
  line varchar(6),
  sequence numeric(2),
  station varchar(32),
  primary key (line, sequence)
);

copy lines
from '/user/projects/project-3-peeti-ucberkeley/code/data/lines.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

my_read_csv_file("data/lines.csv", limit=10)
# Out:
# ['line', 'sequence', 'station']
# ['blue', '1', 'Dublin']
# ['blue', '2', 'West Dublin']
# ['blue', '3', 'Castro Valley']
# ['blue', '4', 'Bay Fair']
# ['blue', '5', 'San Leandro']
# ['blue', '6', 'Coliseum']
# ['blue', '7', 'Fruitvale']
# ['blue', '8', 'Lake Merritt']
# ['blue', '9', 'West Oakland']
#
# Printed  10 lines of  115 total lines.

# %%
# create travel times table and load data

connection.rollback()

query = """

drop table if exists travel_times;
create table travel_times (
  station_1 varchar(32),
  station_2 varchar(32),
  travel_time numeric(3),
  primary key (station_1, station_2)
);

copy travel_times
from '/user/projects/project-3-peeti-ucberkeley/code/data/travel_times.csv' delimiter ',' NULL '' csv header;


"""


cursor.execute(query)

connection.commit()

my_read_csv_file("data/travel_times.csv", limit=10)
# Out:
# ['station_1', 'station_2', 'travel_time']
# ['12th Street', '19th Street', '120']
# ['12th Street', 'Lake Merritt', '180']
# ['12th Street', 'West Oakland', '300']
# ['16th Street Mission', '24th Street Mission', '120']
# ['16th Street Mission', 'Civic Center', '180']
# ['19th Street', 'MacArthur', '180']
# ['24th Street Mission', 'Glen Park', '180']
# ['Antioch', 'Pittsburg Center', '420']
# ['Ashby', 'Downtown Berkeley', '180']
#
# Printed  10 lines of  52 total lines.

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select station from stations
order by station

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#                  station
# 0            12th Street
# 1    16th Street Mission
# 2            19th Street
# 3    24th Street Mission
# 4                Antioch
# 5                  Ashby
# 6            Balboa Park
# 7               Bay Fair
# 8              Berryessa
# 9          Castro Valley
# 10          Civic Center
# 11              Coliseum
# 12                 Colma
# 13               Concord
# 14             Daly City
# 15     Downtown Berkeley
# 16                Dublin
# 17  El Cerrito del Norte
# 18      El Cerrito Plaza
# 19           Embarcadero
# 20               Fremont
# 21             Fruitvale
# 22             Glen Park
# 23               Hayward
# 24             Lafayette
# 25          Lake Merritt
# 26             MacArthur
# 27              Millbrae
# 28              Milpitas
# 29     Montgomery Street
# 30        North Berkeley
# 31         North Concord
# 32                   OAK
# 33                Orinda
# 34             Pittsburg
# 35      Pittsburg Center
# 36         Pleasant Hill
# 37         Powell Street
# 38              Richmond
# 39             Rockridge
# 40             San Bruno
# 41           San Leandro
# 42                   SFO
# 43         South Hayward
# 44   South San Francisco
# 45            Union City
# 46          Walnut Creek
# 47          Warm Springs
# 48           West Dublin
# 49          West Oakland

# %% [markdown]
# # Create peak product table

# %%
connection.rollback()

query = """

drop table if exists peak_product_mapping;
CREATE TABLE peak_product_mapping
( product_id numeric(3) primary key,
  peak_product_id numeric(12)) ;
  
copy peak_product_mapping
from '/user/projects/project-3-peeti-ucberkeley/code/data/peak_product_mapping.csv' delimiter ',' NULL '' csv header;
  

"""

cursor.execute(query)

connection.commit()

my_read_csv_file("data/peak_product_mapping.csv", 10)
# Out:
# ['product_id', 'peak_product_id']
# ['1', '42314677']
# ['2', '42314678']
# ['3', '42314679']
# ['4', '42314780']
# ['5', '42314781']
# ['6', '42314782']
# ['7', '42314783']
# ['8', '42314784']
#
# Printed  9 lines of  9 total lines.

# %% [markdown]
# # parse peak sales from json file to csv and create a table and load data

# %%
def my_recursive_print_json(j, level = -1):
    "given a json object print it"
    
    level += 1
    
    spaces = "    "
    
    if type(j) is dict:
        dict_2_list = list(j.keys())
        for k in dict_2_list:
            print(spaces * level + k)
            my_recursive_print_json(j[k], level)
            
    elif type(j) is list:
        for (i, l) in enumerate(j):
            print(spaces * level + "[" + str(i) + "]")
            my_recursive_print_json(l, level)
                  
    else:
        print(spaces * level + "value:", str(j))
      

def my_read_nested_json(file_name):
    "given a file of json, read it and parse it meaningfully"
    
    f = open(file_name, "r")
    
    j = json.load(f)
    
    f.close
    
    
    my_recursive_print_json(j)
    
my_read_nested_json('data/peak_sales_2020_10_03.json')

# parse the data in csv

def my_extract_peak_sales_2020_nested_json_to_csv(file_name):
    "extract sales nested json to csv files"
    
    f = open(file_name, "r")
    j = json.load(f)
    f.close()   
    
    sale_json_list = []
    store_json_list  = []
    customer_json_list = []
    line_item_json_list = []
    
    for sale in j['sales']:
        
        sale_json = {}
        sale_json['sale_id'] = sale['sale_id']
        sale_json['sale_date'] = sale['sale_date']
        sale_json['sub_total'] = sale['sub_total']
        sale_json['tax'] = sale['tax']
        sale_json['total_amount'] = sale['total_amount']
        
        sale_json_list.append(sale_json)
        
        store_json = {}
        store_json['sale_id'] = sale['sale_id']
        store_json['location_id'] = sale['pickup_from']['location_id'] 
        store_json['name'] = sale['pickup_from']['name']
        store_json['street'] = sale['pickup_from']['street']
        store_json['city'] = sale['pickup_from']['city']
        store_json['state'] = sale['pickup_from']['state']
        store_json['zip'] = sale['pickup_from']['zip']
          
        store_json_list.append(store_json)
        
        customer_json = {}
        customer_json['sale_id'] = sale['sale_id']
        customer_json['customer_id'] = sale['deliver_to']['customer_id'] 
        customer_json['first_name'] = sale['deliver_to']['first_name'] 
        customer_json['last_name'] = sale['deliver_to']['last_name'] 
        customer_json['street'] = sale['deliver_to']['street'] 
        customer_json['city'] = sale['deliver_to']['city']   
        customer_json['state'] = sale['deliver_to']['state'] 
        customer_json['zip'] = sale['deliver_to']['zip']       
         
        customer_json_list.append(customer_json)
        line_item_id = 0
        
        for line_item in sale['line_items']:
               
                
            line_item_json = {}
            line_item_json['sale_id'] = sale['sale_id']
            line_item_id += 1
            line_item_json['line_item_id'] = line_item_id
            line_item_json['product_id'] = line_item['product_id']
            line_item_json['price'] = line_item['price'] 
            line_item_json['quantity'] = line_item['quantity'] 
            line_item_json['taxable'] = line_item['taxable'] 
                
            line_item_json_list.append(line_item_json)
            

            
    f = open("data/peak_sales.csv", "w")
    dw = csv.DictWriter(f, sale_json_list[0].keys())
    dw.writeheader()
    dw.writerows(sale_json_list)
    f.close()
    
    f = open("data/peak_customers.csv", "w")
    dw = csv.DictWriter(f, customer_json_list[0].keys())
    dw.writeheader()
    dw.writerows(customer_json_list)
    f.close()
    
    f = open("data/peak_stores.csv", "w")
    dw = csv.DictWriter(f, store_json_list[0].keys())
    dw.writeheader()
    dw.writerows(store_json_list)
    f.close()
      
    f = open("data/peak_line_items.csv", "w")
    dw = csv.DictWriter(f, line_item_json_list[0].keys())
    dw.writeheader()
    dw.writerows(line_item_json_list)
    f.close()
# Out:
# creator
#     value: Peak Deliveries
# timestamp
#     value: 2020-10-04 02:00:00
# file_name
#     value: peak_sales_2020_10_03.json
# version
#     value: 17.11.7
# legal
#     value: Unauthorized use, duplication, or possession, blah, blah
# sales
#     [0]
#         sale_id
#             value: 5763728874
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 12
#         tax
#             value: 0
#         total_amount
#             value: 12
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728404
#             first_name
#                 value: Darrelle
#             last_name
#                 value: Dohrmann
#             street
#                 value: 46 Farwell Terrace
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94609
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [1]
#         sale_id
#             value: 5763729036
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 72
#         tax
#             value: 0
#         total_amount
#             value: 72
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729309
#             first_name
#                 value: Moria
#             last_name
#                 value: Greenwood
#             street
#                 value: 8803 Delaware Crossing
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [2]
#         sale_id
#             value: 5763728904
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728508
#             first_name
#                 value: Josiah
#             last_name
#                 value: Hulett
#             street
#                 value: 6755 Melby Plaza
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94612
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [3]
#         sale_id
#             value: 5763728973
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 96
#         tax
#             value: 0
#         total_amount
#             value: 96
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728534
#             first_name
#                 value: Gayle
#             last_name
#                 value: MacGarrity
#             street
#                 value: 286 Onsgard Center
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94703
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [4]
#         sale_id
#             value: 5763728757
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 108
#         tax
#             value: 0
#         total_amount
#             value: 108
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729188
#             first_name
#                 value: Courtenay
#             last_name
#                 value: Shirrell
#             street
#                 value: 75 West Park
#             city
#                 value: Emeryville
#             state
#                 value: CA
#             zip
#                 value: 94608
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [5]
#         sale_id
#             value: 5763729051
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 144
#         tax
#             value: 0
#         total_amount
#             value: 144
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729276
#             first_name
#                 value: Christian
#             last_name
#                 value: Anyene
#             street
#                 value: 869 Transport Crossing
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94707
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 4
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [5]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [6]
#         sale_id
#             value: 5763729153
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729242
#             first_name
#                 value: Linnell
#             last_name
#                 value: Barr
#             street
#                 value: 521 Fallview Alley
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94602
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [7]
#         sale_id
#             value: 5763728608
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 96
#         tax
#             value: 0
#         total_amount
#             value: 96
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728705
#             first_name
#                 value: Benedick
#             last_name
#                 value: Staneland
#             street
#                 value: 3852 Laurel Park
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94704
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [8]
#         sale_id
#             value: 5763728696
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 84
#         tax
#             value: 0
#         total_amount
#             value: 84
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729340
#             first_name
#                 value: Lanni
#             last_name
#                 value: Pickavant
#             street
#                 value: 481 Moose Pass
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94609
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [9]
#         sale_id
#             value: 5763728768
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729016
#             first_name
#                 value: Hyrum
#             last_name
#                 value: Knuckles
#             street
#                 value: 86668 Spenser Terrace
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94618
#         line_items
#             [0]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [10]
#         sale_id
#             value: 5763728685
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 96
#         tax
#             value: 0
#         total_amount
#             value: 96
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729233
#             first_name
#                 value: Uriah
#             last_name
#                 value: Breache
#             street
#                 value: 16452 Crowley Way
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94618
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [5]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [11]
#         sale_id
#             value: 5763728787
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 84
#         tax
#             value: 0
#         total_amount
#             value: 84
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728640
#             first_name
#                 value: Jeff
#             last_name
#                 value: Cohane
#             street
#                 value: 23 Kensington Center
#             city
#                 value: El Cerrito
#             state
#                 value: CA
#             zip
#                 value: 94530
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [12]
#         sale_id
#             value: 5763729233
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 36
#         tax
#             value: 0
#         total_amount
#             value: 36
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728406
#             first_name
#                 value: Sibelle
#             last_name
#                 value: Yakov
#             street
#                 value: 2007 Warbler Pass
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94610
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [13]
#         sale_id
#             value: 5763729081
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728831
#             first_name
#                 value: Aurilia
#             last_name
#                 value: Sand
#             street
#                 value: 2187 Carpenter Pass
#             city
#                 value: El Cerrito
#             state
#                 value: CA
#             zip
#                 value: 94530
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [14]
#         sale_id
#             value: 5763728425
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 36
#         tax
#             value: 0
#         total_amount
#             value: 36
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728931
#             first_name
#                 value: Hube
#             last_name
#                 value: Byard
#             street
#                 value: 712 Aberg Street
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94606
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [15]
#         sale_id
#             value: 5763728579
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729206
#             first_name
#                 value: Ardyce
#             last_name
#                 value: Lauderdale
#             street
#                 value: 483 Pearson Point
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94602
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [16]
#         sale_id
#             value: 5763728832
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729081
#             first_name
#                 value: Armand
#             last_name
#                 value: Olyet
#             street
#                 value: 48 Valley Edge Plaza
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [17]
#         sale_id
#             value: 5763728420
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 24
#         tax
#             value: 0
#         total_amount
#             value: 24
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728511
#             first_name
#                 value: Saundra
#             last_name
#                 value: Ameer-Beg
#             street
#                 value: 994 Vernon Center
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94708
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [18]
#         sale_id
#             value: 5763728543
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 36
#         tax
#             value: 0
#         total_amount
#             value: 36
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729222
#             first_name
#                 value: Lulita
#             last_name
#                 value: Pessler
#             street
#                 value: 176 Blue Bill Park Court
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94709
#         line_items
#             [0]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [19]
#         sale_id
#             value: 5763728877
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 108
#         tax
#             value: 0
#         total_amount
#             value: 108
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728936
#             first_name
#                 value: Roseann
#             last_name
#                 value: Coyish
#             street
#                 value: 11707 American Ash Ter
#             city
#                 value: Orinda
#             state
#                 value: CA
#             zip
#                 value: 94563
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 4
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [20]
#         sale_id
#             value: 5763728494
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729012
#             first_name
#                 value: Lavena
#             last_name
#                 value: Toynbee
#             street
#                 value: 37524 Hanover Junction
#             city
#                 value: Emeryville
#             state
#                 value: CA
#             zip
#                 value: 94608
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [21]
#         sale_id
#             value: 5763729291
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 84
#         tax
#             value: 0
#         total_amount
#             value: 84
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729193
#             first_name
#                 value: Baxie
#             last_name
#                 value: Sahnow
#             street
#                 value: 224 Main Terrace
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94606
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [22]
#         sale_id
#             value: 5763728662
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728797
#             first_name
#                 value: Cosmo
#             last_name
#                 value: Frude
#             street
#                 value: 343 Redwing Pass
#             city
#                 value: Orinda
#             state
#                 value: CA
#             zip
#                 value: 94563
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [23]
#         sale_id
#             value: 5763728428
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 72
#         tax
#             value: 0
#         total_amount
#             value: 72
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729287
#             first_name
#                 value: Hali
#             last_name
#                 value: Ducker
#             street
#                 value: 8 Orion Pass
#             city
#                 value: El Cerrito
#             state
#                 value: CA
#             zip
#                 value: 94530
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [5]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [24]
#         sale_id
#             value: 5763728475
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728401
#             first_name
#                 value: Dale
#             last_name
#                 value: Baldacchi
#             street
#                 value: 937 Lotheville Place
#             city
#                 value: Orinda
#             state
#                 value: CA
#             zip
#                 value: 94563
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [25]
#         sale_id
#             value: 5763728393
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728674
#             first_name
#                 value: Melantha
#             last_name
#                 value: Golborn
#             street
#                 value: 6140 North Field Alley
#             city
#                 value: Orinda
#             state
#                 value: CA
#             zip
#                 value: 94563
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [26]
#         sale_id
#             value: 5763728447
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 120
#         tax
#             value: 0
#         total_amount
#             value: 120
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728524
#             first_name
#                 value: Danyette
#             last_name
#                 value: Jillett
#             street
#                 value: 20808 Kipling Plaza
#             city
#                 value: Emeryville
#             state
#                 value: CA
#             zip
#                 value: 94608
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [1]
# ...
#         tax
#             value: 0
#         total_amount
#             value: 36
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728892
#             first_name
#                 value: Brittni
#             last_name
#                 value: Bubb
#             street
#                 value: 37715 Larry Way
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94710
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [89]
#         sale_id
#             value: 5763728679
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 120
#         tax
#             value: 0
#         total_amount
#             value: 120
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728758
#             first_name
#                 value: Cecelia
#             last_name
#                 value: Meece
#             street
#                 value: 33 Westend Point
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94703
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 4
#                 taxable
#                     value: N
#     [90]
#         sale_id
#             value: 5763728666
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 120
#         tax
#             value: 0
#         total_amount
#             value: 120
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729022
#             first_name
#                 value: Liuka
#             last_name
#                 value: Tancock
#             street
#                 value: 68308 Mcbride Road
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94703
#         line_items
#             [0]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 6
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [91]
#         sale_id
#             value: 5763729182
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728373
#             first_name
#                 value: Sunshine
#             last_name
#                 value: Grisard
#             street
#                 value: 149 Laurel Terrace
#             city
#                 value: Oakland
#             state
#                 value: CA
#             zip
#                 value: 94612
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314781
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [92]
#         sale_id
#             value: 5763728927
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 72
#         tax
#             value: 0
#         total_amount
#             value: 72
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728568
#             first_name
#                 value: Valina
#             last_name
#                 value: Spring
#             street
#                 value: 119 Sachtjen Junction
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94702
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314783
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [93]
#         sale_id
#             value: 5763729096
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728990
#             first_name
#                 value: Claire
#             last_name
#                 value: Mebes
#             street
#                 value: 358 Oxford Road
#             city
#                 value: Albany
#             state
#                 value: CA
#             zip
#                 value: 94706
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 3
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [94]
#         sale_id
#             value: 5763729268
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 84
#         tax
#             value: 0
#         total_amount
#             value: 84
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728901
#             first_name
#                 value: Freddy
#             last_name
#                 value: Mumford
#             street
#                 value: 6 Transport Lane
#             city
#                 value: Orinda
#             state
#                 value: CA
#             zip
#                 value: 94563
#         line_items
#             [0]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314679
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314780
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [3]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [4]
#                 product_id
#                     value: 42314784
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#     [95]
#         sale_id
#             value: 5763729237
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 60
#         tax
#             value: 0
#         total_amount
#             value: 60
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3729019
#             first_name
#                 value: Arv
#             last_name
#                 value: Doret
#             street
#                 value: 2120 Mesta Circle
#             city
#                 value: Emeryville
#             state
#                 value: CA
#             zip
#                 value: 94608
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#     [96]
#         sale_id
#             value: 5763728673
#         sale_date
#             value: 2020-10-03
#         sub_total
#             value: 48
#         tax
#             value: 0
#         total_amount
#             value: 48
#         pickup_from
#             location_id
#                 value: 12573
#             name
#                 value: Acme Gourmet Meals
#             street
#                 value: 3000 Telegraph Ave
#             city
#                 value: Berkeley
#             state
#                 value: CA
#             zip
#                 value: 94705
#         deliver_to
#             customer_id
#                 value: 3728691
#             first_name
#                 value: Eula
#             last_name
#                 value: Dewair
#             street
#                 value: 3 Crownhardt Road
#             city
#                 value: Albany
#             state
#                 value: CA
#             zip
#                 value: 94706
#         line_items
#             [0]
#                 product_id
#                     value: 42314677
#                 price
#                     value: 12
#                 quantity
#                     value: 2
#                 taxable
#                     value: N
#             [1]
#                 product_id
#                     value: 42314678
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N
#             [2]
#                 product_id
#                     value: 42314782
#                 price
#                     value: 12
#                 quantity
#                     value: 1
#                 taxable
#                     value: N

# %%
my_extract_peak_sales_2020_nested_json_to_csv('data/peak_sales_2020_10_03.json')

#create a table for peak sales
connection.rollback()

query = """

drop table if exists peak_sales;
create table peak_sales (
  sale_id varchar(100),
  sale_date varchar(100),
  sub_total varchar(100),
  tax varchar(100),
  total_amount varchar(100)
);

copy peak_sales
from '/user/projects/project-3-peeti-ucberkeley/code/data/peak_sales.csv' delimiter ',' NULL '' csv header;


"""


cursor.execute(query)

connection.commit()

my_read_csv_file("data/peak_sales.csv", limit=10)
# Out:
# ['sale_id', 'sale_date', 'sub_total', 'tax', 'total_amount']
# ['5763728874', '2020-10-03', '12', '0', '12']
# ['5763729036', '2020-10-03', '72', '0', '72']
# ['5763728904', '2020-10-03', '24', '0', '24']
# ['5763728973', '2020-10-03', '96', '0', '96']
# ['5763728757', '2020-10-03', '108', '0', '108']
# ['5763729051', '2020-10-03', '144', '0', '144']
# ['5763729153', '2020-10-03', '24', '0', '24']
# ['5763728608', '2020-10-03', '96', '0', '96']
# ['5763728696', '2020-10-03', '84', '0', '84']
#
# Printed  10 lines of  98 total lines.

# %%
#create a table for peak customers
connection.rollback()

query = """

drop table if exists peak_customers;
create table peak_customers (
  
  sale_id varchar(100),
  customer_id varchar(100),
  first_name varchar(100),
  last_name varchar(100),
  street varchar(100),
  city varchar(100),
  state varchar(100),
  zip varchar(100)
);

copy peak_customers
from '/user/projects/project-3-peeti-ucberkeley/code/data/peak_customers.csv' delimiter ',' NULL '' csv header;


"""


cursor.execute(query)

connection.commit()

my_read_csv_file("data/peak_customers.csv", limit=10)
# Out:
# ['sale_id', 'customer_id', 'first_name', 'last_name', 'street', 'city', 'state', 'zip']
# ['5763728874', '3728404', 'Darrelle', 'Dohrmann', '46 Farwell Terrace', 'Oakland', 'CA', '94609']
# ['5763729036', '3729309', 'Moria', 'Greenwood', '8803 Delaware Crossing', 'Berkeley', 'CA', '94705']
# ['5763728904', '3728508', 'Josiah', 'Hulett', '6755 Melby Plaza', 'Oakland', 'CA', '94612']
# ['5763728973', '3728534', 'Gayle', 'MacGarrity', '286 Onsgard Center', 'Berkeley', 'CA', '94703']
# ['5763728757', '3729188', 'Courtenay', 'Shirrell', '75 West Park', 'Emeryville', 'CA', '94608']
# ['5763729051', '3729276', 'Christian', 'Anyene', '869 Transport Crossing', 'Berkeley', 'CA', '94707']
# ['5763729153', '3729242', 'Linnell', 'Barr', '521 Fallview Alley', 'Oakland', 'CA', '94602']
# ['5763728608', '3728705', 'Benedick', 'Staneland', '3852 Laurel Park', 'Berkeley', 'CA', '94704']
# ['5763728696', '3729340', 'Lanni', 'Pickavant', '481 Moose Pass', 'Oakland', 'CA', '94609']
#
# Printed  10 lines of  98 total lines.

# %%
#create a table for peak stores
connection.rollback()

query = """

drop table if exists peak_stores;
create table peak_stores (
  
  sale_id varchar(100),
  location_id varchar(100),
  name varchar(100),
  street varchar(100),
  city varchar(100),
  state varchar(100),
  zip varchar(100)
);

copy peak_stores
from '/user/projects/project-3-peeti-ucberkeley/code/data/peak_stores.csv' delimiter ',' NULL '' csv header;


"""


cursor.execute(query)

connection.commit()

my_read_csv_file("data/peak_stores.csv", limit=10)
# Out:
# ['sale_id', 'location_id', 'name', 'street', 'city', 'state', 'zip']
# ['5763728874', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763729036', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763728904', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763728973', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763728757', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763729051', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763729153', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763728608', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
# ['5763728696', '12573', 'Acme Gourmet Meals', '3000 Telegraph Ave', 'Berkeley', 'CA', '94705']
#
# Printed  10 lines of  98 total lines.

# %%
#create a table for pline item
connection.rollback()

query = """

drop table if exists peak_line_items;
create table peak_line_items (
  
  sale_id varchar(100),
  line_item_id varchar(100),
  product_id varchar(100),
  price varchar(100),
  quantity varchar(100),
  taxable varchar(100)
);

copy peak_line_items
from '/user/projects/project-3-peeti-ucberkeley/code/data/peak_line_items.csv' delimiter ',' NULL '' csv header;


"""


cursor.execute(query)

connection.commit()

my_read_csv_file("data/peak_line_items.csv", limit=10)
# Out:
# ['sale_id', 'line_item_id', 'product_id', 'price', 'quantity', 'taxable']
# ['5763728874', '1', '42314780', '12', '1', 'N']
# ['5763729036', '1', '42314677', '12', '1', 'N']
# ['5763729036', '2', '42314782', '12', '3', 'N']
# ['5763729036', '3', '42314784', '12', '2', 'N']
# ['5763728904', '1', '42314780', '12', '1', 'N']
# ['5763728904', '2', '42314784', '12', '1', 'N']
# ['5763728973', '1', '42314677', '12', '2', 'N']
# ['5763728973', '2', '42314780', '12', '2', 'N']
# ['5763728973', '3', '42314782', '12', '2', 'N']
#
# Printed  10 lines of  353 total lines.

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select zip,
        sum(total_amount::numeric) as total_sales, 
       sum(total_amount::numeric)*0.18 as cut_paid_to_peak,
       sum(total_amount::numeric)*(1-0.18) as net_to_agm
from peak_sales a
join peak_stores b
on a.sale_id = b.sale_id
group by 1
order by 4 desc ;

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#      zip  total_sales  cut_paid_to_peak  net_to_agm
# 0  94705         6480            1166.4      5313.6

# %% [markdown]
# # search with station has highest population

# %%
from geographiclib.geodesic import Geodesic

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

def my_station_get_zips(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    print("\n-------------------------------------------------------------------------------")
    print("  Zip Codes within " + str(miles) + " mile(s) of " + station + " BART Station")
    print("-------------------------------------------------------------------------------\n")
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
        print("     zip:", zip, "  population: ", f'{population:10,}')
        total_population += population
        
    
    print("\n-------------------------------------------------------------------------------")
    print("  Total Population: ", f'{total_population:10,}')
    print("-------------------------------------------------------------------------------")
    
def my_neo4j_shortest_path(from_station, to_station):
    "given a from station and to station, run and print the shortest path"
    
    query = "CALL gds.graph.drop('ds_graph', false)"
    session.run(query)

    query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK', {relationshipProperties: 'weight'})"
    session.run(query)

    query = """

    MATCH (source:Station {name: $source}), (target:Station {name: $target})
    CALL gds.shortestPath.dijkstra.stream(
        'ds_graph', 
        { sourceNode: source, 
          targetNode: target, 
          relationshipWeightProperty: 'weight'
        }
    )
    YIELD index, sourceNode, targetNode, totalCost, nodeIds, costs, path
    RETURN
        gds.util.asNode(sourceNode).name AS from,
        gds.util.asNode(targetNode).name AS to,
        totalCost,
        [nodeId IN nodeIds | gds.util.asNode(nodeId).name] AS nodes,
        costs
    ORDER BY index

    """

    result = session.run(query, source=from_station, target=to_station)
    
    for r in result:
        
        total_cost = int(r['totalCost'])
        
        print("\n--------------------------------")
        print("   Total Cost: ", total_cost)
        print("   Minutes: ", round(total_cost / 60.0,1))
        print("--------------------------------")
        
        nodes = r['nodes']
        costs = r['costs']
        
        i = 0
        previous = 0
        
        for n in nodes:
            
            print(n + ", " + str(int(costs[i]) - previous)  + ", " + str(int(costs[i])))
            
            previous = int(costs[i])
            i += 1

# %% [markdown]
# # within 5 miles radius

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select station from stations group by 1;

"""

station_name = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
l = [list(i) for i in np.array(list(station_name.values))]

station_name_list = [item for sublist in l for item in sublist]
station_name_list
# Out:
# ['Bay Fair',
#  'Fremont',
#  'SFO',
#  'Pittsburg',
#  'Richmond',
#  'Fruitvale',
#  'Hayward',
#  'Ashby',
#  'Downtown Berkeley',
#  'Lafayette',
#  'Dublin',
#  'MacArthur',
#  'El Cerrito Plaza',
#  'Walnut Creek',
#  'San Bruno',
#  'Rockridge',
#  'North Berkeley',
#  'Daly City',
#  'North Concord',
#  'Milpitas',
#  'Union City',
#  'Colma',
#  '24th Street Mission',
#  'South San Francisco',
#  'Pittsburg Center',
#  'El Cerrito del Norte',
#  'OAK',
#  'Powell Street',
#  'Lake Merritt',
#  'Concord',
#  '16th Street Mission',
#  'Coliseum',
#  'Antioch',
#  '12th Street',
#  'Civic Center',
#  'Warm Springs',
#  'Millbrae',
#  'San Leandro',
#  'Berryessa',
#  'Pleasant Hill',
#  'Embarcadero',
#  'Castro Valley',
#  'West Oakland',
#  'Balboa Park',
#  'West Dublin',
#  'Orinda',
#  '19th Street',
#  'Glen Park',
#  'South Hayward',
#  'Montgomery Street']

# %%
[my_station_get_zips(k, 5) for k in station_name_list]
# Out:
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Bay Fair BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94541   population:      66,056
#      zip: 94542   population:      14,217
#      zip: 94544   population:      79,235
#      zip: 94546   population:      44,272
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94580   population:      29,942
#      zip: 94603   population:      34,593
#      zip: 94605   population:      43,112
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     457,901
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Fremont BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94536   population:      73,855
#      zip: 94538   population:      68,111
#      zip: 94539   population:      52,802
#      zip: 94560   population:      46,276
#      zip: 94587   population:      74,601
#
# -------------------------------------------------------------------------------
#   Total Population:     315,645
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of SFO BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94010   population:      42,730
#      zip: 94015   population:      64,887
#      zip: 94030   population:      22,710
#      zip: 94044   population:      39,065
#      zip: 94066   population:      43,124
#      zip: 94080   population:      67,597
#      zip: 94128   population:         135
#      zip: 94401   population:      35,414
#
# -------------------------------------------------------------------------------
#   Total Population:     320,354
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Pittsburg BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94518   population:      28,428
#      zip: 94519   population:      20,121
#      zip: 94521   population:      43,103
#      zip: 94565   population:      96,081
#
# -------------------------------------------------------------------------------
#   Total Population:     187,733
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Richmond BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94564   population:      19,200
#      zip: 94702   population:      17,092
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94801   population:      29,958
#      zip: 94803   population:      26,165
#      zip: 94804   population:      41,510
#      zip: 94805   population:      14,208
#      zip: 94806   population:      64,410
#
# -------------------------------------------------------------------------------
#   Total Population:     301,909
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Fruitvale BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94516   population:         148
#      zip: 94577   population:      48,088
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94603   population:      34,593
#      zip: 94605   population:      43,112
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     544,423
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Hayward BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94541   population:      66,056
#      zip: 94542   population:      14,217
#      zip: 94544   population:      79,235
#      zip: 94545   population:      32,525
#      zip: 94546   population:      44,272
#      zip: 94552   population:      15,412
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94580   population:      29,942
#      zip: 94587   population:      74,601
#
# -------------------------------------------------------------------------------
#   Total Population:     467,447
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Ashby BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94563   population:      19,341
#      zip: 94602   population:      29,933
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94804   population:      41,510
#
# -------------------------------------------------------------------------------
#   Total Population:     487,206
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Downtown Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94563   population:      19,341
#      zip: 94602   population:      29,933
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94804   population:      41,510
#
# -------------------------------------------------------------------------------
#   Total Population:     448,042
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Lafayette BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94516   population:         148
#      zip: 94523   population:      35,096
#      zip: 94549   population:      29,639
#      zip: 94556   population:      16,368
#      zip: 94563   population:      19,341
#      zip: 94575   population:       1,170
#      zip: 94595   population:      17,938
#      zip: 94596   population:      20,822
#      zip: 94597   population:      22,734
#      zip: 94611   population:      39,384
#
# -------------------------------------------------------------------------------
#   Total Population:     202,640
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Dublin BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94566   population:      45,910
#      zip: 94568   population:      54,420
#      zip: 94582   population:      42,059
#      zip: 94583   population:      35,102
#      zip: 94588   population:      36,316
#
# -------------------------------------------------------------------------------
#   Total Population:     213,807
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of MacArthur BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94563   population:      19,341
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     524,629
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of El Cerrito Plaza BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94801   population:      29,958
#      zip: 94803   population:      26,165
#      zip: 94804   population:      41,510
#      zip: 94805   population:      14,208
#
# -------------------------------------------------------------------------------
#   Total Population:     355,903
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Walnut Creek BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94507   population:      15,646
#      zip: 94518   population:      28,428
#      zip: 94523   population:      35,096
#      zip: 94549   population:      29,639
#      zip: 94556   population:      16,368
#      zip: 94575   population:       1,170
#      zip: 94595   population:      17,938
#      zip: 94596   population:      20,822
#      zip: 94597   population:      22,734
#      zip: 94598   population:      27,780
#
# -------------------------------------------------------------------------------
#   Total Population:     215,621
# -------------------------------------------------------------------------------
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of San Bruno BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94010   population:      42,730
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94030   population:      22,710
#      zip: 94044   population:      39,065
#      zip: 94066   population:      43,124
#      zip: 94080   population:      67,597
#      zip: 94128   population:         135
#
# -------------------------------------------------------------------------------
#   Total Population:     334,455
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Rockridge BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94516   population:         148
#      zip: 94563   population:      19,341
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     536,232
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of North Berkeley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94130   population:       3,064
#      zip: 94530   population:      25,754
#      zip: 94602   population:      29,933
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94618   population:      17,041
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94804   population:      41,510
#      zip: 94805   population:      14,208
#
# -------------------------------------------------------------------------------
#   Total Population:     445,973
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Daly City BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94080   population:      67,597
#      zip: 94103   population:      28,735
#      zip: 94107   population:      29,689
#      zip: 94110   population:      74,161
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     805,122
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of North Concord BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94518   population:      28,428
#      zip: 94519   population:      20,121
#      zip: 94520   population:      38,568
#      zip: 94521   population:      43,103
#      zip: 94523   population:      35,096
#
# -------------------------------------------------------------------------------
#   Total Population:     165,316
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Milpitas BART Station
# -------------------------------------------------------------------------------
#
#      zip: 95035   population:      77,562
#      zip: 95050   population:      39,452
#      zip: 95053   population:       3,678
#      zip: 95054   population:      24,264
#      zip: 95110   population:      20,203
#      zip: 95112   population:      61,060
#      zip: 95116   population:      56,481
#      zip: 95127   population:      65,686
#      zip: 95131   population:      31,170
#      zip: 95133   population:      28,726
#      zip: 95134   population:      27,224
#
# -------------------------------------------------------------------------------
#   Total Population:     435,506
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Union City BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94536   population:      73,855
#      zip: 94542   population:      14,217
#      zip: 94544   population:      79,235
#      zip: 94555   population:      38,388
#      zip: 94560   population:      46,276
#      zip: 94587   population:      74,601
#
# -------------------------------------------------------------------------------
#   Total Population:     326,572
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Colma BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94066   population:      43,124
#      zip: 94080   population:      67,597
#      zip: 94110   population:      74,161
#      zip: 94112   population:      85,166
#      zip: 94116   population:      47,823
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94128   population:         135
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94134   population:      42,471
#
# -------------------------------------------------------------------------------
#   Total Population:     597,747
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of 24th Street Mission BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     989,138
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of South San Francisco BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94030   population:      22,710
#      zip: 94044   population:      39,065
#      zip: 94066   population:      43,124
#      zip: 94080   population:      67,597
#      zip: 94112   population:      85,166
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94128   population:         135
#      zip: 94132   population:      31,488
#      zip: 94134   population:      42,471
#
# -------------------------------------------------------------------------------
#   Total Population:     507,636
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Pittsburg Center BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94509   population:      66,933
#      zip: 94521   population:      43,103
#      zip: 94565   population:      96,081
#
# -------------------------------------------------------------------------------
#   Total Population:     206,117
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of El Cerrito del Norte BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94530   population:      25,754
#      zip: 94564   population:      19,200
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94706   population:      21,040
#      zip: 94707   population:      11,916
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#      zip: 94801   population:      29,958
#      zip: 94803   population:      26,165
#      zip: 94804   population:      41,510
#      zip: 94805   population:      14,208
#      zip: 94806   population:      64,410
#
# -------------------------------------------------------------------------------
#   Total Population:     369,372
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of OAK BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94580   population:      29,942
#      zip: 94601   population:      52,299
#      zip: 94603   population:      34,593
#      zip: 94605   population:      43,112
#      zip: 94613   population:         861
#      zip: 94619   population:      24,308
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     410,051
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Powell Street BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     870,044
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Lake Merritt BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94603   population:      34,593
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94621   population:      35,287
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94710   population:       7,461
#
# -------------------------------------------------------------------------------
#   Total Population:     542,120
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Concord BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94518   population:      28,428
#      zip: 94519   population:      20,121
#      zip: 94520   population:      38,568
#      zip: 94521   population:      43,103
#      zip: 94523   population:      35,096
#      zip: 94597   population:      22,734
#
# -------------------------------------------------------------------------------
#   Total Population:     188,050
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of 16th Street Mission BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     870,044
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Coliseum BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94603   population:      34,593
#      zip: 94605   population:      43,112
#      zip: 94606   population:      38,303
#      zip: 94610   population:      31,496
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94619   population:      24,308
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     495,903
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Antioch BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94509   population:      66,933
#      zip: 94531   population:      43,788
#      zip: 94561   population:      41,911
#
# -------------------------------------------------------------------------------
#   Total Population:     152,632
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of 12th Street BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94621   population:      35,287
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     510,498
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Civic Center BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     870,044
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Warm Springs BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94536   population:      73,855
#      zip: 94538   population:      68,111
#      zip: 94539   population:      52,802
#      zip: 94560   population:      46,276
#      zip: 94586   population:         899
#      zip: 95002   population:       2,146
#      zip: 95035   population:      77,562
#
# -------------------------------------------------------------------------------
#   Total Population:     321,651
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Millbrae BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94010   population:      42,730
#      zip: 94030   population:      22,710
#      zip: 94066   population:      43,124
#      zip: 94080   population:      67,597
#      zip: 94128   population:         135
#      zip: 94401   population:      35,414
#      zip: 94402   population:      25,764
#      zip: 94403   population:      44,300
#
# -------------------------------------------------------------------------------
#   Total Population:     281,774
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of San Leandro BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94502   population:      14,619
#      zip: 94541   population:      66,056
#      zip: 94546   population:      44,272
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94580   population:      29,942
#      zip: 94601   population:      52,299
#      zip: 94603   population:      34,593
#      zip: 94605   population:      43,112
#      zip: 94606   population:      38,303
#      zip: 94613   population:         861
#      zip: 94619   population:      24,308
#      zip: 94621   population:      35,287
#
# -------------------------------------------------------------------------------
#   Total Population:     494,839
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Berryessa BART Station
# -------------------------------------------------------------------------------
#
#      zip: 95050   population:      39,452
#      zip: 95053   population:       3,678
#      zip: 95054   population:      24,264
#      zip: 95110   population:      20,203
#      zip: 95112   population:      61,060
#      zip: 95113   population:       1,939
#      zip: 95116   population:      56,481
#      zip: 95117   population:      29,592
#      zip: 95121   population:      38,102
#      zip: 95122   population:      57,780
#      zip: 95126   population:      35,988
#      zip: 95127   population:      65,686
#      zip: 95128   population:      37,665
#      zip: 95131   population:      31,170
#      zip: 95133   population:      28,726
#      zip: 95134   population:      27,224
#
# -------------------------------------------------------------------------------
#   Total Population:     559,010
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Pleasant Hill BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94518   population:      28,428
#      zip: 94519   population:      20,121
#      zip: 94520   population:      38,568
#      zip: 94523   population:      35,096
#      zip: 94549   population:      29,639
#      zip: 94553   population:      49,699
#      zip: 94595   population:      17,938
#      zip: 94596   population:      20,822
#      zip: 94597   population:      22,734
#      zip: 94598   population:      27,780
#
# -------------------------------------------------------------------------------
#   Total Population:     290,825
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Embarcadero BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     698,612
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Castro Valley BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94541   population:      66,056
#      zip: 94542   population:      14,217
#      zip: 94544   population:      79,235
#      zip: 94546   population:      44,272
#      zip: 94552   population:      15,412
#      zip: 94577   population:      48,088
#      zip: 94578   population:      41,059
#      zip: 94579   population:      22,040
#      zip: 94580   population:      29,942
#      zip: 94605   population:      43,112
#
# -------------------------------------------------------------------------------
#   Total Population:     403,433
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of West Oakland BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94130   population:       3,064
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94612   population:      16,062
#      zip: 94618   population:      17,041
#      zip: 94621   population:      35,287
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     473,317
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Balboa Park BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94080   population:      67,597
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94110   population:      74,161
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     936,912
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of West Dublin BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94552   population:      15,412
#      zip: 94566   population:      45,910
#      zip: 94568   population:      54,420
#      zip: 94582   population:      42,059
#      zip: 94583   population:      35,102
#      zip: 94588   population:      36,316
#
# -------------------------------------------------------------------------------
#   Total Population:     229,219
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Orinda BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94516   population:         148
#      zip: 94549   population:      29,639
#      zip: 94556   population:      16,368
#      zip: 94563   population:      19,341
#      zip: 94575   population:       1,170
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94618   population:      17,041
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94708   population:      11,455
#      zip: 94709   population:      11,740
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     262,181
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of 19th Street BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94501   population:      63,843
#      zip: 94502   population:      14,619
#      zip: 94563   population:      19,341
#      zip: 94601   population:      52,299
#      zip: 94602   population:      29,933
#      zip: 94603   population:      34,593
#      zip: 94606   population:      38,303
#      zip: 94607   population:      26,254
#      zip: 94608   population:      30,289
#      zip: 94609   population:      22,811
#      zip: 94610   population:      31,496
#      zip: 94611   population:      39,384
#      zip: 94612   population:      16,062
#      zip: 94613   population:         861
#      zip: 94618   population:      17,041
#      zip: 94621   population:      35,287
#      zip: 94702   population:      17,092
#      zip: 94703   population:      21,937
#      zip: 94704   population:      29,190
#      zip: 94705   population:      13,365
#      zip: 94709   population:      11,740
#      zip: 94710   population:       7,461
#      zip: 94720   population:       2,971
#
# -------------------------------------------------------------------------------
#   Total Population:     576,172
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Glen Park BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94005   population:       4,692
#      zip: 94014   population:      49,515
#      zip: 94015   population:      64,887
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94121   population:      43,795
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     986,074
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of South Hayward BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94536   population:      73,855
#      zip: 94541   population:      66,056
#      zip: 94542   population:      14,217
#      zip: 94544   population:      79,235
#      zip: 94545   population:      32,525
#      zip: 94578   population:      41,059
#      zip: 94580   population:      29,942
#      zip: 94587   population:      74,601
#
# -------------------------------------------------------------------------------
#   Total Population:     411,490
# -------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------
#   Zip Codes within 5 mile(s) of Montgomery Street BART Station
# -------------------------------------------------------------------------------
#
#      zip: 94102   population:      31,067
#      zip: 94103   population:      28,735
#      zip: 94104   population:         546
#      zip: 94105   population:       9,155
#      zip: 94107   population:      29,689
#      zip: 94108   population:      14,550
#      zip: 94109   population:      56,677
#      zip: 94110   population:      74,161
#      zip: 94111   population:       3,620
#      zip: 94112   population:      85,166
#      zip: 94114   population:      34,754
#      zip: 94115   population:      35,004
#      zip: 94116   population:      47,823
#      zip: 94117   population:      44,239
#      zip: 94118   population:      41,468
#      zip: 94122   population:      62,131
#      zip: 94123   population:      25,941
#      zip: 94124   population:      35,363
#      zip: 94127   population:      21,423
#      zip: 94129   population:       3,994
#      zip: 94130   population:       3,064
#      zip: 94131   population:      29,902
#      zip: 94132   population:      31,488
#      zip: 94133   population:      26,527
#      zip: 94134   population:      42,471
#      zip: 94158   population:       7,291
#
# -------------------------------------------------------------------------------
#   Total Population:     826,249
# -------------------------------------------------------------------------------
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # BART Stations that have highest population
# * Montgomery Street = 826,249 **
# * Glen Park = 986,074 **
# * 24th Street Mission = 989,138 **
# * Balboa Park =  936,912
# * Embarcadero = 698,612
# * Civic Center = 870,044
# * 16th Street Mission = 870,044
# * Powell Street = 870,044
# * Daly City = 805,122

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","w205"))
session = driver.session(database="neo4j")
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Montgomery Street')
# Out:
# --------------------------------
#    Total Cost:  1500
#    Minutes:  25.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# arrive Montgomery Street, 0, 1500

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Glen Park')
# Out:
# --------------------------------
#    Total Cost:  2160
#    Minutes:  36.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# red 16th Street Mission, 180, 1860
# red 24th Street Mission, 120, 1980
# red Glen Park, 180, 2160
# arrive Glen Park, 0, 2160

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive 24th Street Mission')
# Out:
# --------------------------------
#    Total Cost:  1980
#    Minutes:  33.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# red 16th Street Mission, 180, 1860
# red 24th Street Mission, 120, 1980
# arrive 24th Street Mission, 0, 1980

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Balboa Park')
# Out:
# --------------------------------
#    Total Cost:  2280
#    Minutes:  38.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# red 16th Street Mission, 180, 1860
# red 24th Street Mission, 120, 1980
# red Glen Park, 180, 2160
# red Balboa Park, 120, 2280
# arrive Balboa Park, 0, 2280

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Embarcadero')
# Out:
# --------------------------------
#    Total Cost:  1440
#    Minutes:  24.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# arrive Embarcadero, 0, 1440

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Civic Center')
# Out:
# --------------------------------
#    Total Cost:  1680
#    Minutes:  28.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# arrive Civic Center, 0, 1680

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive 16th Street Mission')
# Out:
# --------------------------------
#    Total Cost:  1860
#    Minutes:  31.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# red 16th Street Mission, 180, 1860
# arrive 16th Street Mission, 0, 1860

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Powell Street')
# Out:
# --------------------------------
#    Total Cost:  1620
#    Minutes:  27.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# arrive Powell Street, 0, 1620

# %%
my_neo4j_shortest_path('depart Downtown Berkeley' , 'arrive Daly City')
# Out:
# --------------------------------
#    Total Cost:  2520
#    Minutes:  42.0
# --------------------------------
# depart Downtown Berkeley, 0, 0
# red Downtown Berkeley, 0, 0
# red Ashby, 180, 180
# red MacArthur, 240, 420
# red 19th Street, 180, 600
# red 12th Street, 120, 720
# red West Oakland, 300, 1020
# red Embarcadero, 420, 1440
# red Montgomery Street, 60, 1500
# red Powell Street, 120, 1620
# red Civic Center, 60, 1680
# red 16th Street Mission, 180, 1860
# red 24th Street Mission, 120, 1980
# red Glen Park, 180, 2160
# red Balboa Park, 120, 2280
# red Daly City, 240, 2520
# arrive Daly City, 0, 2520
